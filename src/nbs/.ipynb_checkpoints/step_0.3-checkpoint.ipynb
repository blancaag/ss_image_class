# %% [markdown]
# [Bottom](#bottom)<a id='top'.</a>

# %%
import libraries
from libraries import *
# %matplotlib inline

get_available_gpus()
# Out:
# Using TensorFlow backend.
# ['/gpu:0']

# %%
sys.stdout.flush()
print(psutil.virtual_memory())
# Out:
# svmem(total=64390926336, available=43947646976, percent=31.7, used=15900323840, free=39651921920, active=15848144896, inactive=8036200448, buffers=76197888, cached=8762482688, shared=4298960896)

# %%
reload(libraries)
from libraries import *

# %% [markdown]
# ## Loading data and defining generators

# %% [raw]
# Tested things:
# - Normalization of the whole dataset
# - Batch normalization (always included as first layer) - Try to set up Inception on top pf BatchNorm
# - Normalization per sample
# - Normalization feature wise (within the Data Generator)
# - How BN layer works

# %%
path='../data/original/sushi_or_sandwich/'
x_train, y_train, x_test, y_test, mean_set, std_set = load_data(split=0.8, path=path)
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape, mean_set, std_set)
# Out:
# (800, 256, 256, 3) (800,)
# (640, 256, 256, 3) (640,) (160, 256, 256, 3) (160,) 0.527196 0.283016

# %%
x_train_n = (x_train - mean_set) / std_set
x_test_n = (x_test - mean_set) / std_set

x_train_r = x_train * 255
x_test_r = x_test * 255

print(x_test.min(), x_test.max())
print(x_test_n.min(), x_test_n.max())
print(x_test_r.min(), x_test_r.max())
# Out:
# 0.0 1.0
# -1.86277555935 1.67058767286
# 0.0 255.0

# %%
target_size = (256, 256)
num_classes = 1
input_shape = target_size + (3,)

# %% [markdown]
# [Go to Modeling](#section2) <a href='#section2'>Also link to section 2]</a>

# %% [markdown]
# <a id='section1'.</a>

# %% [markdown]
# ## Generators

# %%
# plain generator

data_gen = ImageDataGenerator(rescale=1./255)

# augmented data generators
# rotation_range = 20,width_shift_range=0.5,height_shift_range=0.2):

gen_85 = ImageDataGenerator(
        rotation_range=40,  # 45
        width_shift_range=0.2, # 0.125
        height_shift_range=0.2, # 0.125
        shear_range=0.05, # 0.2
        zoom_range=0.05, # 0.2
        horizontal_flip=True,
        fill_mode='nearest')

gen_0 = ImageDataGenerator(
#         samplewise_center=True, 
#         samplewise_std_normalization=True,
        featurewise_center=True,
        featurewise_std_normalization=True,
        rotation_range=40,  # 45
        width_shift_range=0.2, # 0.125
        height_shift_range=0.2, # 0.125
        shear_range=0.05, # 0.2
        zoom_range=0.05, # 0.2
        horizontal_flip=True,
        fill_mode='nearest')
#         preprocessing_function=rescale_normalize) 

gen_0.fit(x_train, augment=10)

# featurewise_center=False, 
# samplewise_center=False, 
# featurewise_std_normalization=False, 
# samplewise_std_normalization=False, 
# zca_whitening=False, 
# zca_epsilon=1e-06, 
# rotation_range=0.0, 
# width_shift_range=0.0, 
# height_shift_range=0.0, 
# shear_range=0.0, 
# zoom_range=0.0, 
# channel_shift_range=0.0, 
# fill_mode='nearest', 
# cval=0.0, 
# horizontal_flip=False, 
# vertical_flip=False, 
# rescale=None, 
# preprocessing_function=None, 
# data_format=None)


# if including data augmentation

# aug_data_gen_1 = ImageDataGenerator(rotation_range=8, 
#                                width_shift_range=0.08, 
#                                shear_range=0.3,
#                                height_shift_range=0.08, 
#                                zoom_range=0.08)

# Options:
# rotation_range=15, 
# height_shift_range=0.05, 
# shear_range=0.1, 
# channel_shift_range=20, 
# width_shift_range=0.1

## Note: to visualize the aug_gen output uncomment the following lines:

gen_1 = ImageDataGenerator(
    samplewise_center=True, 
    samplewise_std_normalization=True,
    rescale=1./255,
    rotation_range=.9,     
    width_shift_range=.2 , # biggest impact
    height_shift_range=.2, # biggest impact   
    shear_range=.3,
    zoom_range=.3,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

sample = np.empty(((0,) + input_shape))
for i, j in gen_85.flow_from_directory(join(path), batch_size=3, seed=0):

    sample = np.append(sample, i, axis=0); 
    sample_lab = j
    break

plot_images(sample)
# Out:
# Found 800 images belonging to 2 classes.

# %% [markdown]
# #### Data augmentation playground

# %%
# rotation_range = 20,width_shift_range=0.5,height_shift_range=0.2):
import inspect
args = inspect.getfullargspec(ImageDataGenerator)

# # # def iter_gen():
gens = []
for j in range(0, 10, 3): 
    exec("""aug_data_gen_{} = ImageDataGenerator(
            rescale=1./255,
            horizontal_flip=True,
            vertical_flip=True,
            rotation_range=90,             # 
            width_shift_range={}/10,       # 
            height_shift_range=.0,         # 
            shear_range=.05,               # 
            zoom_range=.05,                # 
            fill_mode='nearest')#; print({}/10)
    """.format(j, j, j))
    exec('gens.append(aug_data_gen_{})'.format(j))

sample_folder = 'aug_data_sample'
if not os.path.exists(sample_folder): os.mkdir(sample_folder)

sample = np.empty(((0,) + input_shape))
for gen in gens:
    for i, j in gen.flow_from_directory('../data/sushi_or_sandwich_extended/train/', 
                                         batch_size=3, seed=0,
                                         save_to_dir=sample_folder, save_prefix='ex'):

        sample = np.append(sample, i, axis=0); 
        sample_lab = j
        break
# Out:
# Found 2200 images belonging to 2 classes.
# Found 2200 images belonging to 2 classes.
# Found 2200 images belonging to 2 classes.
# Found 2200 images belonging to 2 classes.

# %%
plot_images(x_train[:3])

# %% [markdown]
# [Go to Generators](#section1)<a id='section2'.</a>

# %% [markdown]
# ## Modelling

# %% [markdown]
# #### Model 0: Inception V3

# %%
output_folder = 'iv3'
if not os.path.exists(output_folder): os.mkdir(output_folder)

input_shape = x_train.shape[1:]

bm0 = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)

# %%
p = 0.5

top_m0 = Sequential([
        BatchNormalization(input_shape=bm0.output_shape[1:]),
        MaxPooling2D(),
        Flatten(),
        Dropout(p),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(p),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(p),
        Dense(1, activation='sigmoid')
        ])

# top_m.summary()

top_m0.compile(Adam(), loss='binary_crossentropy', 
              metrics=['accuracy', recall, precision, fmeasure ])

top_m0.load_weights(output_folder + '/top_model_w_88_0.273.h5')

# %% [markdown]
# [Skip training top model](#section2.2)

# %% [markdown]
# ##### 0.1. Generating features

# %%
# defining generators

aug_data_gen = gen_0
batch_size=16

aug_gen_train = aug_data_gen.flow(x_train, y_train, batch_size=batch_size, shuffle=False)
aug_gen_test = aug_data_gen.flow(x_test, y_test, batch_size=batch_size, shuffle=False)

# calculating IV3 output ('features')

x_da_features = bm0.predict_generator(aug_gen_train, aug_gen_train.n, verbose=1)
y_da_features = np.concatenate([y_train]*batch_size)

save_array(output_folder + '/x_da_features_train', x_da_features)
save_array(output_folder + '/y_da_features_train', y_da_features)

print(x_da_features.shape, y_da_features.shape)

x_da_features_test = bm0.predict_generator(aug_gen_test, aug_gen_test.n, verbose=1)
y_da_features_test = np.concatenate([y_test]*batch_size)

save_array(output_folder + '/x_da_features_test', x_da_features_test)
save_array(output_folder + '/y_da_features_test', y_da_features_test)

print(x_da_features_test.shape, y_da_features_test.shape)

# x_da_features = load_array(output_folder + '/x_da_features_train')
# y_da_features = load_array(output_folder + '/y_da_features_train')

# x_da_features_test = load_array(output_folder + '/x_da_features_test')
# y_da_features_test = load_array(output_folder + '/y_da_features_test')

# print(x_da_features.shape, 
#       y_da_features.shape,
#       x_da_features_test.shape, 
#       y_da_features_test.shape)
# Out:
# 640/640 [==============================] - 140s
# (10240, 6, 6, 2048) (10240,)
# 160/160 [==============================] - 35s
# (2560, 6, 6, 2048) (2560,)

# %% [markdown]
# ##### 0.2. Training top model

# %%
top_m0.optimizer.lr = 0.00001; print(top_m0.optimizer.lr)

batch_size = 128
epochs = 3

th0 = top_m0.fit(x_da_features, y_da_features, batch_size=batch_size, epochs=epochs,
              validation_data=(x_da_features_test, y_da_features_test))
# Out:
# 1e-05
# Train on 10240 samples, validate on 2560 samples
# Epoch 1/5
# 10240/10240 [==============================] - 7s - loss: 0.2853 - acc: 0.8825 - recall: 0.8881 - precision: 0.8817 - fmeasure: 0.8839 - val_loss: 0.2734 - val_acc: 0.8828 - val_recall: 0.8365 - val_precision: 0.9103 - val_fmeasure: 0.8715
# Epoch 2/5
# 10240/10240 [==============================] - 4s - loss: 0.2803 - acc: 0.8873 - recall: 0.8939 - precision: 0.8858 - fmeasure: 0.8888 - val_loss: 0.2684 - val_acc: 0.8844 - val_recall: 0.8431 - val_precision: 0.9077 - val_fmeasure: 0.8739
# Epoch 3/5
# 10240/10240 [==============================] - 4s - loss: 0.2727 - acc: 0.8904 - recall: 0.8984 - precision: 0.8875 - fmeasure: 0.8917 - val_loss: 0.2701 - val_acc: 0.8859 - val_recall: 0.8432 - val_precision: 0.9109 - val_fmeasure: 0.8753
# Epoch 4/5
# 10240/10240 [==============================] - 4s - loss: 0.2587 - acc: 0.8959 - recall: 0.8994 - precision: 0.8967 - fmeasure: 0.8970 - val_loss: 0.2680 - val_acc: 0.8883 - val_recall: 0.8473 - val_precision: 0.9122 - val_fmeasure: 0.8781
# Epoch 5/5
# 10240/10240 [==============================] - 4s - loss: 0.2558 - acc: 0.8972 - recall: 0.8982 - precision: 0.8999 - fmeasure: 0.8980 - val_loss: 0.2678 - val_acc: 0.8879 - val_recall: 0.8448 - val_precision: 0.9135 - val_fmeasure: 0.8774

# %%
plot_hist(th0, 'acc')

# %%
top_m0.save_weights(output_folder + '/top_model_w_88_0.273.h5')

# %% [markdown]
# <a id='section2.2'.</a>

# %% [markdown]
# ##### 0.3. Training the whole model

# %%
m0 = Model(bm0.input, top_m0(bm0.output))

# for i in m1.layers: i.trainable = True
for layer in bm0.layers[:172]:
    layer.trainable = False
for layer in bm0.layers[172:]:
    layer.trainable = True

m0.compile(Adam(), loss='binary_crossentropy', 
           metrics=['accuracy', recall, precision, fmeasure ])

# m0.load_weights(output_folder + '/whole_model_w_9437.h5')

# %%
m0.optimizer.lr = 0.0001; print(m0.optimizer.lr)
aug_data_gen = gen_1
batch_size = 128
epochs = 100

aug_gen = aug_data_gen.flow(x_train, y_train, batch_size=batch_size)

h0 = m0.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs, 
                     validation_data=(x_test, y_test))
# Out:
# 0.0001
# Epoch 1/100
# 5/5 [==============================] - 13s - loss: 0.8286 - acc: 0.7344 - recall: 0.7123 - precision: 0.7532 - fmeasure: 0.7318 - val_loss: 0.4696 - val_acc: 0.8187 - val_recall: 0.9333 - val_precision: 0.7482 - val_fmeasure: 0.8301
# Epoch 2/100
# 5/5 [==============================] - 11s - loss: 0.7703 - acc: 0.7281 - recall: 0.7378 - precision: 0.7288 - fmeasure: 0.7331 - val_loss: 0.4885 - val_acc: 0.8187 - val_recall: 0.9333 - val_precision: 0.7482 - val_fmeasure: 0.8301
# Epoch 3/100
# 5/5 [==============================] - 11s - loss: 0.8150 - acc: 0.7172 - recall: 0.7181 - precision: 0.7209 - fmeasure: 0.7185 - val_loss: 0.4903 - val_acc: 0.8250 - val_recall: 0.9467 - val_precision: 0.7509 - val_fmeasure: 0.8371
# Epoch 4/100
# 5/5 [==============================] - 11s - loss: 0.8454 - acc: 0.7125 - recall: 0.7142 - precision: 0.7191 - fmeasure: 0.7126 - val_loss: 0.4862 - val_acc: 0.8187 - val_recall: 0.9467 - val_precision: 0.7428 - val_fmeasure: 0.8321
# Epoch 5/100
# 5/5 [==============================] - 11s - loss: 0.7540 - acc: 0.7281 - recall: 0.7186 - precision: 0.7376 - fmeasure: 0.7272 - val_loss: 0.4840 - val_acc: 0.8250 - val_recall: 0.9467 - val_precision: 0.7509 - val_fmeasure: 0.8371
# Epoch 6/100
# 5/5 [==============================] - 11s - loss: 0.7333 - acc: 0.7609 - recall: 0.7624 - precision: 0.7677 - fmeasure: 0.7629 - val_loss: 0.4764 - val_acc: 0.8250 - val_recall: 0.9333 - val_precision: 0.7566 - val_fmeasure: 0.8351
# Epoch 7/100
# 5/5 [==============================] - 11s - loss: 0.7849 - acc: 0.7297 - recall: 0.7163 - precision: 0.7407 - fmeasure: 0.7274 - val_loss: 0.4696 - val_acc: 0.8375 - val_recall: 0.9467 - val_precision: 0.7677 - val_fmeasure: 0.8472
# Epoch 8/100
# 5/5 [==============================] - 11s - loss: 0.6855 - acc: 0.7547 - recall: 0.7351 - precision: 0.7715 - fmeasure: 0.7524 - val_loss: 0.4674 - val_acc: 0.8250 - val_recall: 0.9467 - val_precision: 0.7509 - val_fmeasure: 0.8371
# Epoch 9/100
# 5/5 [==============================] - 11s - loss: 0.7019 - acc: 0.7469 - recall: 0.7473 - precision: 0.7504 - fmeasure: 0.7479 - val_loss: 0.4746 - val_acc: 0.8063 - val_recall: 0.9200 - val_precision: 0.7372 - val_fmeasure: 0.8180
# Epoch 10/100
# 5/5 [==============================] - 11s - loss: 0.7057 - acc: 0.7313 - recall: 0.7185 - precision: 0.7415 - fmeasure: 0.7298 - val_loss: 0.4799 - val_acc: 0.8063 - val_recall: 0.9200 - val_precision: 0.7372 - val_fmeasure: 0.8180
# Epoch 11/100
# 5/5 [==============================] - 11s - loss: 0.8154 - acc: 0.7266 - recall: 0.7291 - precision: 0.7317 - fmeasure: 0.7285 - val_loss: 0.4844 - val_acc: 0.8000 - val_recall: 0.9067 - val_precision: 0.7343 - val_fmeasure: 0.8108
# Epoch 12/100
# 5/5 [==============================] - 11s - loss: 0.7889 - acc: 0.7078 - recall: 0.6725 - precision: 0.7293 - fmeasure: 0.6994 - val_loss: 0.4922 - val_acc: 0.7937 - val_recall: 0.9067 - val_precision: 0.7280 - val_fmeasure: 0.8065
# Epoch 13/100
# 5/5 [==============================] - 11s - loss: 0.7182 - acc: 0.7453 - recall: 0.7504 - precision: 0.7495 - fmeasure: 0.7489 - val_loss: 0.5062 - val_acc: 0.7875 - val_recall: 0.9067 - val_precision: 0.7222 - val_fmeasure: 0.8024
# Epoch 14/100
# 3/5 [=================>............] - ETA: 3s - loss: 0.7531 - acc: 0.7318 - recall: 0.7180 - precision: 0.7545 - fmeasure: 0.7350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-cdb7cdabd716> in <module>()
#       7
#       8 h0 = m0.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs,
# ----> 9                      validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.4/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, initial_epoch)
#    1838                     outs = self.train_on_batch(x, y,
#    1839                                                sample_weight=sample_weight,
# -> 1840                                                class_weight=class_weight)
#    1841
#    1842                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1563             ins = x + y + sample_weights
#    1564         self._make_train_function()
# -> 1565         outputs = self.train_function(ins)
#    1566         if len(outputs) == 1:
#    1567             return outputs[0]
#
# /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
sample_ix = random.randint(0, x_test.shape[0])
print("Prediction: \n", np.round(m0.predict(x_test[sample_ix:sample_ix+3])).ravel())
print("Label: \n", y_test[sample_ix:sample_ix+3])
plot_images(x_test[sample_ix:sample_ix+3])
# Out:
# 22
# Prediction:
#  [ 0.  1.  1.]
# Label:
#  [ 0.  1.  0.]

# %%
# sys.stdout.flush()
m0.save_weights(output_folder + '/whole_model_w_90_0.19_0000.h5')

# %%
plot_hist(h0, 'acc'); #evaluate(m0, x_test, y_test)

# %%
## Another option for top_layer with less parameters
bm01 = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)

top_m01 = Sequential([
        BatchNormalization(input_shape=bm0.output_shape[1:]),
        GlobalAveragePooling2D(),
        Dense(4096),
        BatchNormalization(),
        Activation('relu'),
        Dropout(.5),
        Dense(1, activation='sigmoid')])

top_m01.compile(Adam(), loss='binary_crossentropy', 
                metrics=['accuracy', recall, precision, fmeasure])

# top_m01.summary()

# %%
top_m01.optimizer.lr = 0.00001; print(top_m01.optimizer.lr)

batch_size = 128
epochs = 3

th01 = top_m01.fit(x_da_features, y_da_features, batch_size=batch_size, epochs=epochs,
                   validation_data=(x_da_features_test, y_da_features_test))
# Out:
# 1e-05
# Train on 10240 samples, validate on 2560 samples
# Epoch 1/3
# 10240/10240 [==============================] - 3s - loss: 0.1718 - acc: 0.9302 - recall: 0.9297 - precision: 0.9334 - fmeasure: 0.9307 - val_loss: 0.2448 - val_acc: 0.8883 - val_recall: 0.8703 - val_precision: 0.8925 - val_fmeasure: 0.8810
# Epoch 2/3
# 10240/10240 [==============================] - 3s - loss: 0.1512 - acc: 0.9413 - recall: 0.9428 - precision: 0.9422 - fmeasure: 0.9418 - val_loss: 0.2485 - val_acc: 0.8867 - val_recall: 0.8712 - val_precision: 0.8891 - val_fmeasure: 0.8797
# Epoch 3/3
# 10240/10240 [==============================] - 3s - loss: 0.1351 - acc: 0.9460 - recall: 0.9501 - precision: 0.9443 - fmeasure: 0.9463 - val_loss: 0.2522 - val_acc: 0.8867 - val_recall: 0.8597 - val_precision: 0.8982 - val_fmeasure: 0.8781

# %%
top_m01.save_weights(output_folder + '/top_model_01_w_89_0.26_000.h5')

# %%
m01 = Model(bm01.input, top_m01(bm01.output))

# for i in m1.layers: i.trainable = True
for layer in bm01.layers[:172]:
    layer.trainable = False
for layer in bm01.layers[172:]:
    layer.trainable = True

m01.compile(Adam(), loss='binary_crossentropy', 
           metrics=['accuracy', recall, precision, fmeasure ])

# %%
m01.optimizer.lr = 0.00001; print(m01.optimizer.lr)
aug_data_gen = gen_0
batch_size = 128
epochs = 10

aug_gen = aug_data_gen.flow(x_train, y_train, batch_size=batch_size)

h01 = m01.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs, 
                        validation_data=(x_test, y_test))
# Out:
# 1e-05
# Epoch 1/10
# 5/5 [==============================] - 13s - loss: 0.0709 - acc: 0.9797 - recall: 0.9703 - precision: 0.9901 - fmeasure: 0.9800 - val_loss: 0.2983 - val_acc: 0.8938 - val_recall: 0.9083 - val_precision: 0.8744 - val_fmeasure: 0.8910
# Epoch 2/10
# 5/5 [==============================] - 11s - loss: 0.0725 - acc: 0.9781 - recall: 0.9816 - precision: 0.9762 - fmeasure: 0.9787 - val_loss: 0.3013 - val_acc: 0.8938 - val_recall: 0.9083 - val_precision: 0.8744 - val_fmeasure: 0.8910
# Epoch 3/10
# 5/5 [==============================] - 11s - loss: 0.0794 - acc: 0.9719 - recall: 0.9742 - precision: 0.9710 - fmeasure: 0.9720 - val_loss: 0.3029 - val_acc: 0.8812 - val_recall: 0.8817 - val_precision: 0.8714 - val_fmeasure: 0.8764
# Epoch 4/10
# 5/5 [==============================] - 11s - loss: 0.0663 - acc: 0.9734 - recall: 0.9691 - precision: 0.9780 - fmeasure: 0.9734 - val_loss: 0.3054 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 5/10
# 5/5 [==============================] - 11s - loss: 0.0600 - acc: 0.9797 - recall: 0.9878 - precision: 0.9720 - fmeasure: 0.9797 - val_loss: 0.3081 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 6/10
# 5/5 [==============================] - 11s - loss: 0.0550 - acc: 0.9859 - recall: 0.9867 - precision: 0.9868 - fmeasure: 0.9865 - val_loss: 0.3105 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 7/10
# 5/5 [==============================] - 11s - loss: 0.0553 - acc: 0.9859 - recall: 0.9906 - precision: 0.9815 - fmeasure: 0.9859 - val_loss: 0.3120 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 8/10
# 5/5 [==============================] - 11s - loss: 0.0654 - acc: 0.9813 - recall: 0.9847 - precision: 0.9783 - fmeasure: 0.9813 - val_loss: 0.3130 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 9/10
# 5/5 [==============================] - 11s - loss: 0.0468 - acc: 0.9875 - recall: 0.9821 - precision: 0.9938 - fmeasure: 0.9878 - val_loss: 0.3156 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692
# Epoch 10/10
# 5/5 [==============================] - 11s - loss: 0.0568 - acc: 0.9859 - recall: 0.9880 - precision: 0.9835 - fmeasure: 0.9857 - val_loss: 0.3177 - val_acc: 0.8750 - val_recall: 0.8692 - val_precision: 0.8692 - val_fmeasure: 0.8692

# %%
plot_hist(h01, 'loss')

# %%
m01.save_weights(output_folder + '/whole_model_01_w_89_0.28_0000.h5')

# %% [markdown]
# [Top](#top)<a id='bottom'.</a>

# %% [markdown]
# #### InceptionV3 + Initial Batchnorm Layer

# %%
initial_batchnorm = Sequential([BatchNormalization(input_shape=input_shape)])
# input_tensor = Input(tensor=initial_batchnorm.output)
bm1 = InceptionV3(include_top=False, weights='imagenet', input_shape=initial_batchnorm.output_shape[1:])
bm1_ = Model(initial_batchnorm.input, bm1(initial_batchnorm.output))
bm1_.summary()

top_m1 = top_m0 # top_m01

m1 = Model(bm1_.input, top_m1(bm1_.output))

for layer in bm1.layers[:172]:
    layer.trainable = False
for layer in bm1.layers[172:]:
    layer.trainable = True

m1.compile(Adam(), loss='binary_crossentropy', 
           metrics=['accuracy', recall, precision, fmeasure ])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_627_inpu (None, 256, 256, 3)       0
# _________________________________________________________________
# batch_normalization_627 (Bat (None, 256, 256, 3)       12
# _________________________________________________________________
# inception_v3 (Model)         (None, 6, 6, 2048)        21802784
# =================================================================
# Total params: 21,802,796
# Trainable params: 21,768,358
# Non-trainable params: 34,438
# _________________________________________________________________

# %%
m1.optimizer.lr = 0.00001; print(m1.optimizer.lr)
aug_data_gen = gen_0
batch_size = 128
epochs = 10

aug_gen = aug_data_gen.flow(x_train, y_train, batch_size=batch_size)

h1 = m1.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs, 
                      validation_data=(x_test, y_test))
# Out:
# 1e-05
# Epoch 1/10
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#
# /usr/lib/python3.4/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,96,29,29]
# 	 [[Node: inception_v3/conv2d_582/convolution = Conv2D[T=DT_FLOAT, data_format="NHWC", padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/gpu:0"](inception_v3/activation_599/Relu, conv2d_582/kernel/read)]]
# 	 [[Node: Mean_278/_31297 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_41204_Mean_278", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-192-0e500d85a5af> in <module>()
#       7
#       8 h1 = m1.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs,
# ----> 9                       validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.4/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, initial_epoch)
#    1838                     outs = self.train_on_batch(x, y,
#    1839                                                sample_weight=sample_weight,
# -> 1840                                                class_weight=class_weight)
#    1841
#    1842                     if not isinstance(outs, list):
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1563             ins = x + y + sample_weights
#    1564         self._make_train_function()
# -> 1565         outputs = self.train_function(ins)
#    1566         if len(outputs) == 1:
#    1567             return outputs[0]
#
# /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1150         except KeyError:
#    1151           pass
# -> 1152       raise type(e)(node_def, op, message)
#    1153
#    1154   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,96,29,29]
# 	 [[Node: inception_v3/conv2d_582/convolution = Conv2D[T=DT_FLOAT, data_format="NHWC", padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/gpu:0"](inception_v3/activation_599/Relu, conv2d_582/kernel/read)]]
# 	 [[Node: Mean_278/_31297 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_41204_Mean_278", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
#
# Caused by op 'inception_v3/conv2d_582/convolution', defined at:
#   File "/usr/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.4/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.4/dist-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python3.4/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.4/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.4/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.4/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.4/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.4/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.4/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-191-816edfec585b>", line 4, in <module>
#     bm1_ = Model(initial_batchnorm.input, bm1(initial_batchnorm.output))
#   File "/usr/local/lib/python3.4/dist-packages/keras/engine/topology.py", line 596, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/usr/local/lib/python3.4/dist-packages/keras/engine/topology.py", line 2061, in call
#     output_tensors, _, _ = self.run_internal_graph(inputs, masks)
#   File "/usr/local/lib/python3.4/dist-packages/keras/engine/topology.py", line 2212, in run_internal_graph
#     output_tensors = _to_list(layer.call(computed_tensor, **kwargs))
#   File "/usr/local/lib/python3.4/dist-packages/keras/layers/convolutional.py", line 164, in call
#     dilation_rate=self.dilation_rate)
#   File "/usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py", line 3156, in conv2d
#     data_format='NHWC')
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/nn_ops.py", line 670, in convolution
#     op=op)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/nn_ops.py", line 338, in with_space_to_batch
#     return op(input, num_spatial_dims, padding)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/nn_ops.py", line 662, in op
#     name=name)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/nn_ops.py", line 131, in _non_atrous_convolution
#     name=name)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/ops/gen_nn_ops.py", line 399, in conv2d
#     data_format=data_format, name=name)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/usr/local/lib/python3.4/dist-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[128,96,29,29]
# 	 [[Node: inception_v3/conv2d_582/convolution = Conv2D[T=DT_FLOAT, data_format="NHWC", padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/gpu:0"](inception_v3/activation_599/Relu, conv2d_582/kernel/read)]]
# 	 [[Node: Mean_278/_31297 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/cpu:0", send_device="/job:localhost/replica:0/task:0/gpu:0", send_device_incarnation=1, tensor_name="edge_41204_Mean_278", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"]()]]

# %% [markdown]
# #### Xception + Initial Batchnorm Layer

# %%
initial_batchnorm = Sequential([BatchNormalization(input_shape=input_shape)])
# input_tensor = Input(tensor=initial_batchnorm.output)
bm2 = Xception(include_top=False, weights='imagenet', input_shape=initial_batchnorm.output_shape[1:])
bm2_ = Model(initial_batchnorm.input, bm2(initial_batchnorm.output))
bm2_.summary()

top_m2 = top_0; top_m2.summary()
top_m2 = top_01; top_m2.summary()

m2 = Model(bm2_.input, top_m2(bm2_.output))

for layer in bm2.layers[:172]:
    layer.trainable = False
for layer in bm2.layers[172:]:
    layer.trainable = True

m2.compile(Adam(), loss='binary_crossentropy', 
           metrics=['accuracy', recall, precision, fmeasure ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-6271db96a538> in <module>()
#       1 initial_batchnorm = Sequential([BatchNormalization(input_shape=input_shape)])
#       2 # input_tensor = Input(tensor=initial_batchnorm.output)
# ----> 3 bm2 = InceptionV3(include_top=False, weights='imagenet', input_shape=initial_batchnorm.output_shape[1:])
#       4 # bm2_ = Model(initial_batchnorm.input, bm2(initial_batchnorm.output))
#       5 # bm2_.summary()
#
# /usr/local/lib/python3.4/dist-packages/keras/applications/inception_v3.py in InceptionV3(include_top, weights, input_tensor, input_shape, pooling, classes)
#     383                 cache_subdir='models',
#     384                 md5_hash='bcbd6486424b2319ff4ef7d526e38f63')
# --> 385         model.load_weights(weights_path)
#     386     return model
#     387
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/topology.py in load_weights(self, filepath, by_name)
#    2570             load_weights_from_hdf5_group_by_name(f, self.layers)
#    2571         else:
# -> 2572             load_weights_from_hdf5_group(f, self.layers)
#    2573
#    2574         if hasattr(f, 'close'):
#
# /usr/local/lib/python3.4/dist-packages/keras/engine/topology.py in load_weights_from_hdf5_group(f, layers)
#    3046                              ' elements.')
#    3047         weight_value_tuples += zip(symbolic_weights, weight_values)
# -> 3048     K.batch_set_value(weight_value_tuples)
#    3049
#    3050
#
# /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2186             assign_ops.append(assign_op)
#    2187             feed_dict[assign_placeholder] = value
# -> 2188         get_session().run(assign_ops, feed_dict=feed_dict)
#    2189
#    2190
#
# /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py in get_session()
#     166     if not _MANUAL_VAR_INIT:
#     167         with session.graph.as_default():
# --> 168             _initialize_variables()
#     169     return session
#     170
#
# /usr/local/lib/python3.4/dist-packages/keras/backend/tensorflow_backend.py in _initialize_variables()
#     339     if uninitialized_variables:
#     340         sess = get_session()
# --> 341         sess.run(tf.variables_initializer(uninitialized_variables))
#     342
#     343
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     982     # Create a fetch handler to take care of the structure of fetches.
#     983     fetch_handler = _FetchHandler(
# --> 984         self._graph, fetches, feed_dict_string, feed_handles=feed_handles)
#     985
#     986     # Run request and get response.
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     418       fetch_name = compat.as_bytes(fetch.name)
#     419       if isinstance(fetch, ops.Operation):
# --> 420         self._assert_fetchable(graph, fetch)
#     421         self._targets.append(fetch_name)
#     422         self._ops.append(True)
#
# /usr/local/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _assert_fetchable(self, graph, op)
#     435     if not graph.is_fetchable(op):
#     436       raise ValueError(
# --> 437           'Operation %r has been marked as not fetchable.' % op.name)
#     438
#     439   def fetches(self):
#
# ValueError: Operation 'init_55' has been marked as not fetchable.

# %%
bm2.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-196-82c88141cfe2> in <module>()
# ----> 1 bm2.summary()
#
# NameError: name 'bm2' is not defined

# %%
## original

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=Input(shape=(299, 299, 3)))
x = base_model.output
x = GlobalAveragePooling2D()(x)
# # x = Flatten()(x)
x = Dense(4096)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

# # x = base_model.output
# # x = AveragePooling2D((8, 8), strides=(8, 8), name='avg_pool')(x)
# # x = Flatten(name='flatten')(x)
# # predictions = Dense(101, activation='softmax', name='predictions')(x)

model = Model(input=base_model.input, output=predictions)

# for layer in base_model.layers:
#     layer.trainable = False

# model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
#               metrics=['accuracy'])

# print("First pass")
# checkpointer = ModelCheckpoint(filepath='/home/stratospark/Code/AI/food101/first.3.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True)
# csv_logger = CSVLogger('first.3.log')
# model.fit_generator(generator,
#                     validation_data=val_generator,
#                     nb_val_samples=10000,
#                     samples_per_epoch=X_train.shape[0],
#                     nb_epoch=10,
#                     verbose=1,
#                     callbacks=[csv_logger, checkpointer])

# for layer in model.layers[:172]:
#     layer.trainable = False
# for layer in model.layers[172:]:
#     layer.trainable = True

# print("Second pass")
# model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
# checkpointer = ModelCheckpoint(filepath='/home/stratospark/Code/AI/food101/second.3.{epoch:02d}-{val_loss:.2f}.hdf5', verbose=1, save_best_only=True)
# csv_logger = CSVLogger('second.3.log')
# model.fit_generator(generator,
#                     validation_data=val_generator,
#                     nb_val_samples=10000,
#                     samples_per_epoch=X_train.shape[0],
#                     nb_epoch=100,
#                     verbose=1,
#                     callbacks=[csv_logger, checkpointer])

# %%
base_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_5 (InputLayer)             (None, 299, 299, 3)   0
# ____________________________________________________________________________________________________
# conv2d_377 (Conv2D)              (None, 149, 149, 32)  864         input_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_414 (BatchNo (None, 149, 149, 32)  96          conv2d_377[0][0]
# ____________________________________________________________________________________________________
# activation_383 (Activation)      (None, 149, 149, 32)  0           batch_normalization_414[0][0]
# ____________________________________________________________________________________________________
# conv2d_378 (Conv2D)              (None, 147, 147, 32)  9216        activation_383[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_415 (BatchNo (None, 147, 147, 32)  96          conv2d_378[0][0]
# ____________________________________________________________________________________________________
# activation_384 (Activation)      (None, 147, 147, 32)  0           batch_normalization_415[0][0]
# ____________________________________________________________________________________________________
# conv2d_379 (Conv2D)              (None, 147, 147, 64)  18432       activation_384[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_416 (BatchNo (None, 147, 147, 64)  192         conv2d_379[0][0]
# ____________________________________________________________________________________________________
# activation_385 (Activation)      (None, 147, 147, 64)  0           batch_normalization_416[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D)  (None, 73, 73, 64)    0           activation_385[0][0]
# ____________________________________________________________________________________________________
# conv2d_380 (Conv2D)              (None, 73, 73, 80)    5120        max_pooling2d_27[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_417 (BatchNo (None, 73, 73, 80)    240         conv2d_380[0][0]
# ____________________________________________________________________________________________________
# activation_386 (Activation)      (None, 73, 73, 80)    0           batch_normalization_417[0][0]
# ____________________________________________________________________________________________________
# conv2d_381 (Conv2D)              (None, 71, 71, 192)   138240      activation_386[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_418 (BatchNo (None, 71, 71, 192)   576         conv2d_381[0][0]
# ____________________________________________________________________________________________________
# activation_387 (Activation)      (None, 71, 71, 192)   0           batch_normalization_418[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D)  (None, 35, 35, 192)   0           activation_387[0][0]
# ____________________________________________________________________________________________________
# conv2d_385 (Conv2D)              (None, 35, 35, 64)    12288       max_pooling2d_28[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_422 (BatchNo (None, 35, 35, 64)    192         conv2d_385[0][0]
# ____________________________________________________________________________________________________
# activation_391 (Activation)      (None, 35, 35, 64)    0           batch_normalization_422[0][0]
# ____________________________________________________________________________________________________
# conv2d_383 (Conv2D)              (None, 35, 35, 48)    9216        max_pooling2d_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_386 (Conv2D)              (None, 35, 35, 96)    55296       activation_391[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_420 (BatchNo (None, 35, 35, 48)    144         conv2d_383[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_423 (BatchNo (None, 35, 35, 96)    288         conv2d_386[0][0]
# ____________________________________________________________________________________________________
# activation_389 (Activation)      (None, 35, 35, 48)    0           batch_normalization_420[0][0]
# ____________________________________________________________________________________________________
# activation_392 (Activation)      (None, 35, 35, 96)    0           batch_normalization_423[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_37 (AveragePoo (None, 35, 35, 192)   0           max_pooling2d_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_382 (Conv2D)              (None, 35, 35, 64)    12288       max_pooling2d_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_384 (Conv2D)              (None, 35, 35, 64)    76800       activation_389[0][0]
# ____________________________________________________________________________________________________
# conv2d_387 (Conv2D)              (None, 35, 35, 96)    82944       activation_392[0][0]
# ____________________________________________________________________________________________________
# conv2d_388 (Conv2D)              (None, 35, 35, 32)    6144        average_pooling2d_37[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_419 (BatchNo (None, 35, 35, 64)    192         conv2d_382[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_421 (BatchNo (None, 35, 35, 64)    192         conv2d_384[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_424 (BatchNo (None, 35, 35, 96)    288         conv2d_387[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_425 (BatchNo (None, 35, 35, 32)    96          conv2d_388[0][0]
# ____________________________________________________________________________________________________
# activation_388 (Activation)      (None, 35, 35, 64)    0           batch_normalization_419[0][0]
# ____________________________________________________________________________________________________
# activation_390 (Activation)      (None, 35, 35, 64)    0           batch_normalization_421[0][0]
# ____________________________________________________________________________________________________
# activation_393 (Activation)      (None, 35, 35, 96)    0           batch_normalization_424[0][0]
# ____________________________________________________________________________________________________
# activation_394 (Activation)      (None, 35, 35, 32)    0           batch_normalization_425[0][0]
# ____________________________________________________________________________________________________
# mixed0 (Concatenate)             (None, 35, 35, 256)   0           activation_388[0][0]
#                                                                    activation_390[0][0]
#                                                                    activation_393[0][0]
#                                                                    activation_394[0][0]
# ____________________________________________________________________________________________________
# conv2d_392 (Conv2D)              (None, 35, 35, 64)    16384       mixed0[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_429 (BatchNo (None, 35, 35, 64)    192         conv2d_392[0][0]
# ____________________________________________________________________________________________________
# activation_398 (Activation)      (None, 35, 35, 64)    0           batch_normalization_429[0][0]
# ____________________________________________________________________________________________________
# conv2d_390 (Conv2D)              (None, 35, 35, 48)    12288       mixed0[0][0]
# ____________________________________________________________________________________________________
# conv2d_393 (Conv2D)              (None, 35, 35, 96)    55296       activation_398[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_427 (BatchNo (None, 35, 35, 48)    144         conv2d_390[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_430 (BatchNo (None, 35, 35, 96)    288         conv2d_393[0][0]
# ____________________________________________________________________________________________________
# activation_396 (Activation)      (None, 35, 35, 48)    0           batch_normalization_427[0][0]
# ____________________________________________________________________________________________________
# activation_399 (Activation)      (None, 35, 35, 96)    0           batch_normalization_430[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_38 (AveragePoo (None, 35, 35, 256)   0           mixed0[0][0]
# ____________________________________________________________________________________________________
# conv2d_389 (Conv2D)              (None, 35, 35, 64)    16384       mixed0[0][0]
# ____________________________________________________________________________________________________
# conv2d_391 (Conv2D)              (None, 35, 35, 64)    76800       activation_396[0][0]
# ____________________________________________________________________________________________________
# conv2d_394 (Conv2D)              (None, 35, 35, 96)    82944       activation_399[0][0]
# ____________________________________________________________________________________________________
# conv2d_395 (Conv2D)              (None, 35, 35, 64)    16384       average_pooling2d_38[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_426 (BatchNo (None, 35, 35, 64)    192         conv2d_389[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_428 (BatchNo (None, 35, 35, 64)    192         conv2d_391[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_431 (BatchNo (None, 35, 35, 96)    288         conv2d_394[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_432 (BatchNo (None, 35, 35, 64)    192         conv2d_395[0][0]
# ____________________________________________________________________________________________________
# activation_395 (Activation)      (None, 35, 35, 64)    0           batch_normalization_426[0][0]
# ____________________________________________________________________________________________________
# activation_397 (Activation)      (None, 35, 35, 64)    0           batch_normalization_428[0][0]
# ____________________________________________________________________________________________________
# activation_400 (Activation)      (None, 35, 35, 96)    0           batch_normalization_431[0][0]
# ____________________________________________________________________________________________________
# activation_401 (Activation)      (None, 35, 35, 64)    0           batch_normalization_432[0][0]
# ____________________________________________________________________________________________________
# mixed1 (Concatenate)             (None, 35, 35, 288)   0           activation_395[0][0]
#                                                                    activation_397[0][0]
#                                                                    activation_400[0][0]
#                                                                    activation_401[0][0]
# ____________________________________________________________________________________________________
# conv2d_399 (Conv2D)              (None, 35, 35, 64)    18432       mixed1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_436 (BatchNo (None, 35, 35, 64)    192         conv2d_399[0][0]
# ____________________________________________________________________________________________________
# activation_405 (Activation)      (None, 35, 35, 64)    0           batch_normalization_436[0][0]
# ____________________________________________________________________________________________________
# conv2d_397 (Conv2D)              (None, 35, 35, 48)    13824       mixed1[0][0]
# ____________________________________________________________________________________________________
# conv2d_400 (Conv2D)              (None, 35, 35, 96)    55296       activation_405[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_434 (BatchNo (None, 35, 35, 48)    144         conv2d_397[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_437 (BatchNo (None, 35, 35, 96)    288         conv2d_400[0][0]
# ____________________________________________________________________________________________________
# activation_403 (Activation)      (None, 35, 35, 48)    0           batch_normalization_434[0][0]
# ____________________________________________________________________________________________________
# activation_406 (Activation)      (None, 35, 35, 96)    0           batch_normalization_437[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_39 (AveragePoo (None, 35, 35, 288)   0           mixed1[0][0]
# ____________________________________________________________________________________________________
# conv2d_396 (Conv2D)              (None, 35, 35, 64)    18432       mixed1[0][0]
# ____________________________________________________________________________________________________
# conv2d_398 (Conv2D)              (None, 35, 35, 64)    76800       activation_403[0][0]
# ____________________________________________________________________________________________________
# conv2d_401 (Conv2D)              (None, 35, 35, 96)    82944       activation_406[0][0]
# ____________________________________________________________________________________________________
# conv2d_402 (Conv2D)              (None, 35, 35, 64)    18432       average_pooling2d_39[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_433 (BatchNo (None, 35, 35, 64)    192         conv2d_396[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_435 (BatchNo (None, 35, 35, 64)    192         conv2d_398[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_438 (BatchNo (None, 35, 35, 96)    288         conv2d_401[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_439 (BatchNo (None, 35, 35, 64)    192         conv2d_402[0][0]
# ____________________________________________________________________________________________________
# activation_402 (Activation)      (None, 35, 35, 64)    0           batch_normalization_433[0][0]
# ____________________________________________________________________________________________________
# activation_404 (Activation)      (None, 35, 35, 64)    0           batch_normalization_435[0][0]
# ____________________________________________________________________________________________________
# activation_407 (Activation)      (None, 35, 35, 96)    0           batch_normalization_438[0][0]
# ____________________________________________________________________________________________________
# activation_408 (Activation)      (None, 35, 35, 64)    0           batch_normalization_439[0][0]
# ____________________________________________________________________________________________________
# mixed2 (Concatenate)             (None, 35, 35, 288)   0           activation_402[0][0]
#                                                                    activation_404[0][0]
#                                                                    activation_407[0][0]
#                                                                    activation_408[0][0]
# ____________________________________________________________________________________________________
# conv2d_404 (Conv2D)              (None, 35, 35, 64)    18432       mixed2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_441 (BatchNo (None, 35, 35, 64)    192         conv2d_404[0][0]
# ____________________________________________________________________________________________________
# activation_410 (Activation)      (None, 35, 35, 64)    0           batch_normalization_441[0][0]
# ____________________________________________________________________________________________________
# conv2d_405 (Conv2D)              (None, 35, 35, 96)    55296       activation_410[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_442 (BatchNo (None, 35, 35, 96)    288         conv2d_405[0][0]
# ____________________________________________________________________________________________________
# activation_411 (Activation)      (None, 35, 35, 96)    0           batch_normalization_442[0][0]
# ____________________________________________________________________________________________________
# conv2d_403 (Conv2D)              (None, 17, 17, 384)   995328      mixed2[0][0]
# ____________________________________________________________________________________________________
# conv2d_406 (Conv2D)              (None, 17, 17, 96)    82944       activation_411[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_440 (BatchNo (None, 17, 17, 384)   1152        conv2d_403[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_443 (BatchNo (None, 17, 17, 96)    288         conv2d_406[0][0]
# ____________________________________________________________________________________________________
# activation_409 (Activation)      (None, 17, 17, 384)   0           batch_normalization_440[0][0]
# ____________________________________________________________________________________________________
# activation_412 (Activation)      (None, 17, 17, 96)    0           batch_normalization_443[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D)  (None, 17, 17, 288)   0           mixed2[0][0]
# ____________________________________________________________________________________________________
# mixed3 (Concatenate)             (None, 17, 17, 768)   0           activation_409[0][0]
#                                                                    activation_412[0][0]
#                                                                    max_pooling2d_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_411 (Conv2D)              (None, 17, 17, 128)   98304       mixed3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_448 (BatchNo (None, 17, 17, 128)   384         conv2d_411[0][0]
# ____________________________________________________________________________________________________
# activation_417 (Activation)      (None, 17, 17, 128)   0           batch_normalization_448[0][0]
# ____________________________________________________________________________________________________
# conv2d_412 (Conv2D)              (None, 17, 17, 128)   114688      activation_417[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_449 (BatchNo (None, 17, 17, 128)   384         conv2d_412[0][0]
# ____________________________________________________________________________________________________
# activation_418 (Activation)      (None, 17, 17, 128)   0           batch_normalization_449[0][0]
# ____________________________________________________________________________________________________
# conv2d_408 (Conv2D)              (None, 17, 17, 128)   98304       mixed3[0][0]
# ____________________________________________________________________________________________________
# conv2d_413 (Conv2D)              (None, 17, 17, 128)   114688      activation_418[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_445 (BatchNo (None, 17, 17, 128)   384         conv2d_408[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_450 (BatchNo (None, 17, 17, 128)   384         conv2d_413[0][0]
# ____________________________________________________________________________________________________
# activation_414 (Activation)      (None, 17, 17, 128)   0           batch_normalization_445[0][0]
# ____________________________________________________________________________________________________
# activation_419 (Activation)      (None, 17, 17, 128)   0           batch_normalization_450[0][0]
# ____________________________________________________________________________________________________
# conv2d_409 (Conv2D)              (None, 17, 17, 128)   114688      activation_414[0][0]
# ____________________________________________________________________________________________________
# conv2d_414 (Conv2D)              (None, 17, 17, 128)   114688      activation_419[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_446 (BatchNo (None, 17, 17, 128)   384         conv2d_409[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_451 (BatchNo (None, 17, 17, 128)   384         conv2d_414[0][0]
# ____________________________________________________________________________________________________
# activation_415 (Activation)      (None, 17, 17, 128)   0           batch_normalization_446[0][0]
# ____________________________________________________________________________________________________
# activation_420 (Activation)      (None, 17, 17, 128)   0           batch_normalization_451[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_40 (AveragePoo (None, 17, 17, 768)   0           mixed3[0][0]
# ____________________________________________________________________________________________________
# conv2d_407 (Conv2D)              (None, 17, 17, 192)   147456      mixed3[0][0]
# ____________________________________________________________________________________________________
# conv2d_410 (Conv2D)              (None, 17, 17, 192)   172032      activation_415[0][0]
# ____________________________________________________________________________________________________
# conv2d_415 (Conv2D)              (None, 17, 17, 192)   172032      activation_420[0][0]
# ____________________________________________________________________________________________________
# conv2d_416 (Conv2D)              (None, 17, 17, 192)   147456      average_pooling2d_40[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_444 (BatchNo (None, 17, 17, 192)   576         conv2d_407[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_447 (BatchNo (None, 17, 17, 192)   576         conv2d_410[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_452 (BatchNo (None, 17, 17, 192)   576         conv2d_415[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_453 (BatchNo (None, 17, 17, 192)   576         conv2d_416[0][0]
# ____________________________________________________________________________________________________
# activation_413 (Activation)      (None, 17, 17, 192)   0           batch_normalization_444[0][0]
# ____________________________________________________________________________________________________
# activation_416 (Activation)      (None, 17, 17, 192)   0           batch_normalization_447[0][0]
# ____________________________________________________________________________________________________
# activation_421 (Activation)      (None, 17, 17, 192)   0           batch_normalization_452[0][0]
# ____________________________________________________________________________________________________
# activation_422 (Activation)      (None, 17, 17, 192)   0           batch_normalization_453[0][0]
# ____________________________________________________________________________________________________
# mixed4 (Concatenate)             (None, 17, 17, 768)   0           activation_413[0][0]
#                                                                    activation_416[0][0]
#                                                                    activation_421[0][0]
#                                                                    activation_422[0][0]
# ____________________________________________________________________________________________________
# conv2d_421 (Conv2D)              (None, 17, 17, 160)   122880      mixed4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_458 (BatchNo (None, 17, 17, 160)   480         conv2d_421[0][0]
# ____________________________________________________________________________________________________
# activation_427 (Activation)      (None, 17, 17, 160)   0           batch_normalization_458[0][0]
# ____________________________________________________________________________________________________
# conv2d_422 (Conv2D)              (None, 17, 17, 160)   179200      activation_427[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_459 (BatchNo (None, 17, 17, 160)   480         conv2d_422[0][0]
# ____________________________________________________________________________________________________
# activation_428 (Activation)      (None, 17, 17, 160)   0           batch_normalization_459[0][0]
# ____________________________________________________________________________________________________
# conv2d_418 (Conv2D)              (None, 17, 17, 160)   122880      mixed4[0][0]
# ____________________________________________________________________________________________________
# conv2d_423 (Conv2D)              (None, 17, 17, 160)   179200      activation_428[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_455 (BatchNo (None, 17, 17, 160)   480         conv2d_418[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_460 (BatchNo (None, 17, 17, 160)   480         conv2d_423[0][0]
# ____________________________________________________________________________________________________
# activation_424 (Activation)      (None, 17, 17, 160)   0           batch_normalization_455[0][0]
# ____________________________________________________________________________________________________
# activation_429 (Activation)      (None, 17, 17, 160)   0           batch_normalization_460[0][0]
# ____________________________________________________________________________________________________
# conv2d_419 (Conv2D)              (None, 17, 17, 160)   179200      activation_424[0][0]
# ____________________________________________________________________________________________________
# conv2d_424 (Conv2D)              (None, 17, 17, 160)   179200      activation_429[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_456 (BatchNo (None, 17, 17, 160)   480         conv2d_419[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_461 (BatchNo (None, 17, 17, 160)   480         conv2d_424[0][0]
# ____________________________________________________________________________________________________
# activation_425 (Activation)      (None, 17, 17, 160)   0           batch_normalization_456[0][0]
# ____________________________________________________________________________________________________
# activation_430 (Activation)      (None, 17, 17, 160)   0           batch_normalization_461[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_41 (AveragePoo (None, 17, 17, 768)   0           mixed4[0][0]
# ____________________________________________________________________________________________________
# conv2d_417 (Conv2D)              (None, 17, 17, 192)   147456      mixed4[0][0]
# ____________________________________________________________________________________________________
# conv2d_420 (Conv2D)              (None, 17, 17, 192)   215040      activation_425[0][0]
# ____________________________________________________________________________________________________
# conv2d_425 (Conv2D)              (None, 17, 17, 192)   215040      activation_430[0][0]
# ____________________________________________________________________________________________________
# conv2d_426 (Conv2D)              (None, 17, 17, 192)   147456      average_pooling2d_41[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_454 (BatchNo (None, 17, 17, 192)   576         conv2d_417[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_457 (BatchNo (None, 17, 17, 192)   576         conv2d_420[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_462 (BatchNo (None, 17, 17, 192)   576         conv2d_425[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_463 (BatchNo (None, 17, 17, 192)   576         conv2d_426[0][0]
# ____________________________________________________________________________________________________
# activation_423 (Activation)      (None, 17, 17, 192)   0           batch_normalization_454[0][0]
# ____________________________________________________________________________________________________
# activation_426 (Activation)      (None, 17, 17, 192)   0           batch_normalization_457[0][0]
# ____________________________________________________________________________________________________
# activation_431 (Activation)      (None, 17, 17, 192)   0           batch_normalization_462[0][0]
# ____________________________________________________________________________________________________
# activation_432 (Activation)      (None, 17, 17, 192)   0           batch_normalization_463[0][0]
# ____________________________________________________________________________________________________
# mixed5 (Concatenate)             (None, 17, 17, 768)   0           activation_423[0][0]
#                                                                    activation_426[0][0]
#                                                                    activation_431[0][0]
#                                                                    activation_432[0][0]
# ____________________________________________________________________________________________________
# conv2d_431 (Conv2D)              (None, 17, 17, 160)   122880      mixed5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_468 (BatchNo (None, 17, 17, 160)   480         conv2d_431[0][0]
# ____________________________________________________________________________________________________
# activation_437 (Activation)      (None, 17, 17, 160)   0           batch_normalization_468[0][0]
# ____________________________________________________________________________________________________
# conv2d_432 (Conv2D)              (None, 17, 17, 160)   179200      activation_437[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_469 (BatchNo (None, 17, 17, 160)   480         conv2d_432[0][0]
# ____________________________________________________________________________________________________
# activation_438 (Activation)      (None, 17, 17, 160)   0           batch_normalization_469[0][0]
# ____________________________________________________________________________________________________
# conv2d_428 (Conv2D)              (None, 17, 17, 160)   122880      mixed5[0][0]
# ____________________________________________________________________________________________________
# conv2d_433 (Conv2D)              (None, 17, 17, 160)   179200      activation_438[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_465 (BatchNo (None, 17, 17, 160)   480         conv2d_428[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_470 (BatchNo (None, 17, 17, 160)   480         conv2d_433[0][0]
# ____________________________________________________________________________________________________
# activation_434 (Activation)      (None, 17, 17, 160)   0           batch_normalization_465[0][0]
# ____________________________________________________________________________________________________
# activation_439 (Activation)      (None, 17, 17, 160)   0           batch_normalization_470[0][0]
# ____________________________________________________________________________________________________
# conv2d_429 (Conv2D)              (None, 17, 17, 160)   179200      activation_434[0][0]
# ____________________________________________________________________________________________________
# conv2d_434 (Conv2D)              (None, 17, 17, 160)   179200      activation_439[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_466 (BatchNo (None, 17, 17, 160)   480         conv2d_429[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_471 (BatchNo (None, 17, 17, 160)   480         conv2d_434[0][0]
# ____________________________________________________________________________________________________
# activation_435 (Activation)      (None, 17, 17, 160)   0           batch_normalization_466[0][0]
# ____________________________________________________________________________________________________
# activation_440 (Activation)      (None, 17, 17, 160)   0           batch_normalization_471[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_42 (AveragePoo (None, 17, 17, 768)   0           mixed5[0][0]
# ____________________________________________________________________________________________________
# conv2d_427 (Conv2D)              (None, 17, 17, 192)   147456      mixed5[0][0]
# ____________________________________________________________________________________________________
# conv2d_430 (Conv2D)              (None, 17, 17, 192)   215040      activation_435[0][0]
# ____________________________________________________________________________________________________
# conv2d_435 (Conv2D)              (None, 17, 17, 192)   215040      activation_440[0][0]
# ____________________________________________________________________________________________________
# conv2d_436 (Conv2D)              (None, 17, 17, 192)   147456      average_pooling2d_42[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_464 (BatchNo (None, 17, 17, 192)   576         conv2d_427[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_467 (BatchNo (None, 17, 17, 192)   576         conv2d_430[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_472 (BatchNo (None, 17, 17, 192)   576         conv2d_435[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_473 (BatchNo (None, 17, 17, 192)   576         conv2d_436[0][0]
# ____________________________________________________________________________________________________
# activation_433 (Activation)      (None, 17, 17, 192)   0           batch_normalization_464[0][0]
# ____________________________________________________________________________________________________
# activation_436 (Activation)      (None, 17, 17, 192)   0           batch_normalization_467[0][0]
# ____________________________________________________________________________________________________
# activation_441 (Activation)      (None, 17, 17, 192)   0           batch_normalization_472[0][0]
# ____________________________________________________________________________________________________
# activation_442 (Activation)      (None, 17, 17, 192)   0           batch_normalization_473[0][0]
# ____________________________________________________________________________________________________
# mixed6 (Concatenate)             (None, 17, 17, 768)   0           activation_433[0][0]
#                                                                    activation_436[0][0]
#                                                                    activation_441[0][0]
#                                                                    activation_442[0][0]
# ____________________________________________________________________________________________________
# conv2d_441 (Conv2D)              (None, 17, 17, 192)   147456      mixed6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_478 (BatchNo (None, 17, 17, 192)   576         conv2d_441[0][0]
# ____________________________________________________________________________________________________
# activation_447 (Activation)      (None, 17, 17, 192)   0           batch_normalization_478[0][0]
# ____________________________________________________________________________________________________
# conv2d_442 (Conv2D)              (None, 17, 17, 192)   258048      activation_447[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_479 (BatchNo (None, 17, 17, 192)   576         conv2d_442[0][0]
# ____________________________________________________________________________________________________
# activation_448 (Activation)      (None, 17, 17, 192)   0           batch_normalization_479[0][0]
# ____________________________________________________________________________________________________
# conv2d_438 (Conv2D)              (None, 17, 17, 192)   147456      mixed6[0][0]
# ____________________________________________________________________________________________________
# conv2d_443 (Conv2D)              (None, 17, 17, 192)   258048      activation_448[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_475 (BatchNo (None, 17, 17, 192)   576         conv2d_438[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_480 (BatchNo (None, 17, 17, 192)   576         conv2d_443[0][0]
# ____________________________________________________________________________________________________
# activation_444 (Activation)      (None, 17, 17, 192)   0           batch_normalization_475[0][0]
# ____________________________________________________________________________________________________
# activation_449 (Activation)      (None, 17, 17, 192)   0           batch_normalization_480[0][0]
# ____________________________________________________________________________________________________
# conv2d_439 (Conv2D)              (None, 17, 17, 192)   258048      activation_444[0][0]
# ____________________________________________________________________________________________________
# conv2d_444 (Conv2D)              (None, 17, 17, 192)   258048      activation_449[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_476 (BatchNo (None, 17, 17, 192)   576         conv2d_439[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_481 (BatchNo (None, 17, 17, 192)   576         conv2d_444[0][0]
# ____________________________________________________________________________________________________
# activation_445 (Activation)      (None, 17, 17, 192)   0           batch_normalization_476[0][0]
# ____________________________________________________________________________________________________
# activation_450 (Activation)      (None, 17, 17, 192)   0           batch_normalization_481[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_43 (AveragePoo (None, 17, 17, 768)   0           mixed6[0][0]
# ____________________________________________________________________________________________________
# conv2d_437 (Conv2D)              (None, 17, 17, 192)   147456      mixed6[0][0]
# ____________________________________________________________________________________________________
# conv2d_440 (Conv2D)              (None, 17, 17, 192)   258048      activation_445[0][0]
# ____________________________________________________________________________________________________
# conv2d_445 (Conv2D)              (None, 17, 17, 192)   258048      activation_450[0][0]
# ____________________________________________________________________________________________________
# conv2d_446 (Conv2D)              (None, 17, 17, 192)   147456      average_pooling2d_43[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_474 (BatchNo (None, 17, 17, 192)   576         conv2d_437[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_477 (BatchNo (None, 17, 17, 192)   576         conv2d_440[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_482 (BatchNo (None, 17, 17, 192)   576         conv2d_445[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_483 (BatchNo (None, 17, 17, 192)   576         conv2d_446[0][0]
# ____________________________________________________________________________________________________
# activation_443 (Activation)      (None, 17, 17, 192)   0           batch_normalization_474[0][0]
# ____________________________________________________________________________________________________
# activation_446 (Activation)      (None, 17, 17, 192)   0           batch_normalization_477[0][0]
# ____________________________________________________________________________________________________
# ...
# activation_453 (Activation)      (None, 17, 17, 192)   0           batch_normalization_484[0][0]
# ____________________________________________________________________________________________________
# activation_457 (Activation)      (None, 17, 17, 192)   0           batch_normalization_488[0][0]
# ____________________________________________________________________________________________________
# conv2d_448 (Conv2D)              (None, 8, 8, 320)     552960      activation_453[0][0]
# ____________________________________________________________________________________________________
# conv2d_452 (Conv2D)              (None, 8, 8, 192)     331776      activation_457[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_485 (BatchNo (None, 8, 8, 320)     960         conv2d_448[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_489 (BatchNo (None, 8, 8, 192)     576         conv2d_452[0][0]
# ____________________________________________________________________________________________________
# activation_454 (Activation)      (None, 8, 8, 320)     0           batch_normalization_485[0][0]
# ____________________________________________________________________________________________________
# activation_458 (Activation)      (None, 8, 8, 192)     0           batch_normalization_489[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D)  (None, 8, 8, 768)     0           mixed7[0][0]
# ____________________________________________________________________________________________________
# mixed8 (Concatenate)             (None, 8, 8, 1280)    0           activation_454[0][0]
#                                                                    activation_458[0][0]
#                                                                    max_pooling2d_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_457 (Conv2D)              (None, 8, 8, 448)     573440      mixed8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_494 (BatchNo (None, 8, 8, 448)     1344        conv2d_457[0][0]
# ____________________________________________________________________________________________________
# activation_463 (Activation)      (None, 8, 8, 448)     0           batch_normalization_494[0][0]
# ____________________________________________________________________________________________________
# conv2d_454 (Conv2D)              (None, 8, 8, 384)     491520      mixed8[0][0]
# ____________________________________________________________________________________________________
# conv2d_458 (Conv2D)              (None, 8, 8, 384)     1548288     activation_463[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_491 (BatchNo (None, 8, 8, 384)     1152        conv2d_454[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_495 (BatchNo (None, 8, 8, 384)     1152        conv2d_458[0][0]
# ____________________________________________________________________________________________________
# activation_460 (Activation)      (None, 8, 8, 384)     0           batch_normalization_491[0][0]
# ____________________________________________________________________________________________________
# activation_464 (Activation)      (None, 8, 8, 384)     0           batch_normalization_495[0][0]
# ____________________________________________________________________________________________________
# conv2d_455 (Conv2D)              (None, 8, 8, 384)     442368      activation_460[0][0]
# ____________________________________________________________________________________________________
# conv2d_456 (Conv2D)              (None, 8, 8, 384)     442368      activation_460[0][0]
# ____________________________________________________________________________________________________
# conv2d_459 (Conv2D)              (None, 8, 8, 384)     442368      activation_464[0][0]
# ____________________________________________________________________________________________________
# conv2d_460 (Conv2D)              (None, 8, 8, 384)     442368      activation_464[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_44 (AveragePoo (None, 8, 8, 1280)    0           mixed8[0][0]
# ____________________________________________________________________________________________________
# conv2d_453 (Conv2D)              (None, 8, 8, 320)     409600      mixed8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_492 (BatchNo (None, 8, 8, 384)     1152        conv2d_455[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_493 (BatchNo (None, 8, 8, 384)     1152        conv2d_456[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_496 (BatchNo (None, 8, 8, 384)     1152        conv2d_459[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_497 (BatchNo (None, 8, 8, 384)     1152        conv2d_460[0][0]
# ____________________________________________________________________________________________________
# conv2d_461 (Conv2D)              (None, 8, 8, 192)     245760      average_pooling2d_44[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_490 (BatchNo (None, 8, 8, 320)     960         conv2d_453[0][0]
# ____________________________________________________________________________________________________
# activation_461 (Activation)      (None, 8, 8, 384)     0           batch_normalization_492[0][0]
# ____________________________________________________________________________________________________
# activation_462 (Activation)      (None, 8, 8, 384)     0           batch_normalization_493[0][0]
# ____________________________________________________________________________________________________
# activation_465 (Activation)      (None, 8, 8, 384)     0           batch_normalization_496[0][0]
# ____________________________________________________________________________________________________
# activation_466 (Activation)      (None, 8, 8, 384)     0           batch_normalization_497[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_498 (BatchNo (None, 8, 8, 192)     576         conv2d_461[0][0]
# ____________________________________________________________________________________________________
# activation_459 (Activation)      (None, 8, 8, 320)     0           batch_normalization_490[0][0]
# ____________________________________________________________________________________________________
# mixed9_0 (Concatenate)           (None, 8, 8, 768)     0           activation_461[0][0]
#                                                                    activation_462[0][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, 8, 8, 768)     0           activation_465[0][0]
#                                                                    activation_466[0][0]
# ____________________________________________________________________________________________________
# activation_467 (Activation)      (None, 8, 8, 192)     0           batch_normalization_498[0][0]
# ____________________________________________________________________________________________________
# mixed9 (Concatenate)             (None, 8, 8, 2048)    0           activation_459[0][0]
#                                                                    mixed9_0[0][0]
#                                                                    concatenate_9[0][0]
#                                                                    activation_467[0][0]
# ____________________________________________________________________________________________________
# conv2d_466 (Conv2D)              (None, 8, 8, 448)     917504      mixed9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_503 (BatchNo (None, 8, 8, 448)     1344        conv2d_466[0][0]
# ____________________________________________________________________________________________________
# activation_472 (Activation)      (None, 8, 8, 448)     0           batch_normalization_503[0][0]
# ____________________________________________________________________________________________________
# conv2d_463 (Conv2D)              (None, 8, 8, 384)     786432      mixed9[0][0]
# ____________________________________________________________________________________________________
# conv2d_467 (Conv2D)              (None, 8, 8, 384)     1548288     activation_472[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_500 (BatchNo (None, 8, 8, 384)     1152        conv2d_463[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_504 (BatchNo (None, 8, 8, 384)     1152        conv2d_467[0][0]
# ____________________________________________________________________________________________________
# activation_469 (Activation)      (None, 8, 8, 384)     0           batch_normalization_500[0][0]
# ____________________________________________________________________________________________________
# activation_473 (Activation)      (None, 8, 8, 384)     0           batch_normalization_504[0][0]
# ____________________________________________________________________________________________________
# conv2d_464 (Conv2D)              (None, 8, 8, 384)     442368      activation_469[0][0]
# ____________________________________________________________________________________________________
# conv2d_465 (Conv2D)              (None, 8, 8, 384)     442368      activation_469[0][0]
# ____________________________________________________________________________________________________
# conv2d_468 (Conv2D)              (None, 8, 8, 384)     442368      activation_473[0][0]
# ____________________________________________________________________________________________________
# conv2d_469 (Conv2D)              (None, 8, 8, 384)     442368      activation_473[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_45 (AveragePoo (None, 8, 8, 2048)    0           mixed9[0][0]
# ____________________________________________________________________________________________________
# conv2d_462 (Conv2D)              (None, 8, 8, 320)     655360      mixed9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_501 (BatchNo (None, 8, 8, 384)     1152        conv2d_464[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_502 (BatchNo (None, 8, 8, 384)     1152        conv2d_465[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_505 (BatchNo (None, 8, 8, 384)     1152        conv2d_468[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_506 (BatchNo (None, 8, 8, 384)     1152        conv2d_469[0][0]
# ____________________________________________________________________________________________________
# conv2d_470 (Conv2D)              (None, 8, 8, 192)     393216      average_pooling2d_45[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_499 (BatchNo (None, 8, 8, 320)     960         conv2d_462[0][0]
# ____________________________________________________________________________________________________
# activation_470 (Activation)      (None, 8, 8, 384)     0           batch_normalization_501[0][0]
# ____________________________________________________________________________________________________
# activation_471 (Activation)      (None, 8, 8, 384)     0           batch_normalization_502[0][0]
# ____________________________________________________________________________________________________
# activation_474 (Activation)      (None, 8, 8, 384)     0           batch_normalization_505[0][0]
# ____________________________________________________________________________________________________
# activation_475 (Activation)      (None, 8, 8, 384)     0           batch_normalization_506[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_507 (BatchNo (None, 8, 8, 192)     576         conv2d_470[0][0]
# ____________________________________________________________________________________________________
# activation_468 (Activation)      (None, 8, 8, 320)     0           batch_normalization_499[0][0]
# ____________________________________________________________________________________________________
# mixed9_1 (Concatenate)           (None, 8, 8, 768)     0           activation_470[0][0]
#                                                                    activation_471[0][0]
# ____________________________________________________________________________________________________
# concatenate_10 (Concatenate)     (None, 8, 8, 768)     0           activation_474[0][0]
#                                                                    activation_475[0][0]
# ____________________________________________________________________________________________________
# activation_476 (Activation)      (None, 8, 8, 192)     0           batch_normalization_507[0][0]
# ____________________________________________________________________________________________________
# mixed10 (Concatenate)            (None, 8, 8, 2048)    0           activation_468[0][0]
#                                                                    mixed9_1[0][0]
#                                                                    concatenate_10[0][0]
#                                                                    activation_476[0][0]
# ====================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# ____________________________________________________________________________________________________

# %%
base_model.output.shape
# Out:
# TensorShape([Dimension(None), Dimension(8), Dimension(8), Dimension(2048)])

# %%
'''Visualization of the filters of VGG16, via gradient ascent in input space.
This script can run on CPU in a few minutes (with the TensorFlow backend).
Results example: http://i.imgur.com/4nj4KjN.jpg
'''
from __future__ import print_function

from scipy.misc import imsave
import numpy as np
import time
from keras.applications import vgg16
from keras import backend as K

# dimensions of the generated pictures for each filter.
img_width = 128
img_height = 128

# the name of the layer we want to visualize
# (see model definition at keras/applications/vgg16.py)
layer_name = 'block5_conv1'

# util function to convert a tensor into a valid image


def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_data_format() == 'channels_first':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# build the VGG16 network with ImageNet weights
model = vgg16.VGG16(weights='imagenet', include_top=False)
print('Model loaded.')

model.summary()

# this is the placeholder for the input images
input_img = model.input

# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers[1:]])


def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + 1e-5)


kept_filters = []
for filter_index in range(0, 200):
    # we only scan through the first 200 filters,
    # but there are actually 512 of them
    print('Processing filter %d' % filter_index)
    start_time = time.time()

    # we build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    if K.image_data_format() == 'channels_first':
        loss = K.mean(layer_output[:, filter_index, :, :])
    else:
        loss = K.mean(layer_output[:, :, :, filter_index])

    # we compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads = normalize(grads)

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_img], [loss, grads])

    # step size for gradient ascent
    step = 1.

    # we start from a gray image with some random noise
    if K.image_data_format() == 'channels_first':
        input_img_data = np.random.random((1, 3, img_width, img_height))
    else:
        input_img_data = np.random.random((1, img_width, img_height, 3))
    input_img_data = (input_img_data - 0.5) * 20 + 128

    # we run gradient ascent for 20 steps
    for i in range(20):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step

        print('Current loss value:', loss_value)
        if loss_value <= 0.:
            # some filters get stuck to 0, we can skip them
            break

    # decode the resulting input image
    if loss_value > 0:
        img = deprocess_image(input_img_data[0])
        kept_filters.append((img, loss_value))
    end_time = time.time()
    print('Filter %d processed in %ds' % (filter_index, end_time - start_time))

# we will stich the best 64 filters on a 8 x 8 grid.
n = 8

# the filters that have the highest loss are assumed to be better-looking.
# we will only keep the top 64 filters.
kept_filters.sort(key=lambda x: x[1], reverse=True)
kept_filters = kept_filters[:n * n]

# build a black picture with enough space for
# our 8 x 8 filters of size 128 x 128, with a 5px margin in between
margin = 5
width = n * img_width + (n - 1) * margin
height = n * img_height + (n - 1) * margin
stitched_filters = np.zeros((width, height, 3))

# fill the picture with our saved filters
for i in range(n):
    for j in range(n):
        img, loss = kept_filters[i * n + j]
        stitched_filters[(img_width + margin) * i: (img_width + margin) * i + img_width,
                         (img_height + margin) * j: (img_height + margin) * j + img_height, :] = img

# save the result to disk
imsave('stitched_filters_%dx%d.png' % (n, n), stitched_filters)
# Out:
# TensorShape([Dimension(None), Dimension(1)])

# %%
model = m0

kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
kfold_metrics = {}
for train, test in kfold.split(x, y):        
        metrics = model.evaluate(x[test], y[test], verbose=0)
        for i,j in zip(model.metrics_names, range(len(metrics))):
            print("%s: %.2f%%" % (i, metrics[j] * 100))
#             kfold_metrics[i] = .add(3)#kfold_metrics[i].append(metrics[j] * 100)

# print(kfold_metrics)
# aug_gen = aug_data_gen.flow(x_train, y_train, batch_size=batch_size)

# h0 = m0.fit_generator(aug_gen, x_train.shape[0]//batch_size, epochs=epochs, 
#                      validation_data=(x_test, y_test))
